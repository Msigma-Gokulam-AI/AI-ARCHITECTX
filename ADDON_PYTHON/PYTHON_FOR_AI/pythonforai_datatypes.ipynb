# %% [markdown]
# Alice opens her **IDE workbench** (Google Colab) and uses the built-in **`print()`** function to cleanly display her name on the screen.

# %%
print("Bob")
# Out:
# Bob

# %% [markdown]
# # **Variables**

# %%
#Each marks enter manually
total_score = 78 + 85 + 92 + 69 + 76
print(total_score)
# Out:
# 400

# %% [markdown]
# # **Data Types**

# %% [markdown]
# **1.String**

# %%
username = "Alice123"
username = "Bob1234"
print(username)
# Out:
# Bob1234

# %% [markdown]
# **2.Integers**

# %%
num = 21
print(num)
# Out:
# 21

# %% [markdown]
# **3.Float**

# %%
weight = 179.8
print(weight)
# Out:
# 179.8

# %% [markdown]
# **4. Boolean**
#
# Boolean is a built-in data type that represents only two values: ***True*** and **False**.

# %%
is_male = True
print(is_male)
# Out:
# True
